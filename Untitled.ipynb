# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# This won't be necessary if you have loaded the modules before starting the job:
import os
os.environ['CUDA_HOME'] = "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/cudacore/10.1.243/"

# %%
# !python train.py --wandb '../datasets/summer_to_winter/trainA/' '../datasets/summer_to_winter/trainB/'
# Out:
# d: 0.9434; c: 1.2825 g: 2.1027; g_cooccur: 0.8713; recon: 0.2222; r1: 0.0196; r1
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# d: 1.1892; c: 1.2052 g: 1.7466; g_cooccur: 1.0571; recon: 0.1953; r1: 0.0210; r1
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# d: 0.6917; c: 1.2722 g: 3.2345; g_cooccur: 0.9334; recon: 0.1858; r1: 0.0275; r1
# IOPub message rate exceeded.
# ...

# %%
import os
import torch
import numpy as np
from PIL import Image
from torch.utils import data
import matplotlib.pyplot as plt
from torch.nn import functional as F
from torch import nn, autograd, optim
from stylegan2.datasets.cityscapes import Cityscapes
from stylegan2.datasets.seasons import Seasons
from stylegan2.datasets.wami import WAMI

# %%
path_1 = '../datasets/summer_to_winter/trainA/'
path_2 ='../datasets/summer_to_winter/trainB/'

dataset = Seasons(path_2)

# %%
dataset[1].shape
# Out:
# torch.Size([3, 256, 256])

# %%
plt.imshow(np.transpose((dataset[10]+1)*0.5, (1, 2, 0)))

# %%
! nvidia-smi
# Out:
# Mon Feb 15 19:20:01 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 455.45.01    CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:18:00.0 Off |                    0 |
# | N/A   52C    P0   251W / 300W |  25687MiB / 32510MiB |     95%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...
